# %%
# TODO: change `cwd` to the absolute path that this repo is located in
cwd = "/content/drive/MyDrive/WeatherNetCode/deraining-models/"

from google.colab import drive
drive.mount('/content/drive')
# %cd {cwd}

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from compare_images import ImgCompare
from tqdm.notebook import tqdm

display_groups = False
particulars = None

# !mkdir images/metrics
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1v-jmrok5Mcn8HaN1GHzyJgz_evjZ-23G/WeatherNetCode/deraining-models-experiments/dm-test-ED-weights

# %%
# !bash ./images/copy.sh

# %% [markdown]
# # Efficient Derain

# %% [markdown]
# SPA-V3

# %%
ic = ImgCompare('ED-v3', single=False, progress_func=tqdm, particulars=particulars)
ic.find_metrics(display_groups=display_groups, save=True)

# %% [markdown]
# SPA-V4

# %%
ic = ImgCompare('ED-v4', single=False, progress_func=tqdm, particulars=particulars)
ic.find_metrics(display_groups=display_groups, save=True)

# %%
ic = ImgCompare('ED-v3rain100h', single=False, progress_func=tqdm, particulars=particulars)
ic.find_metrics(display_groups=display_groups, save=True)

# %%
ic = ImgCompare('ED-v4rain100h', single=False, progress_func=tqdm, particulars=particulars)
ic.find_metrics(display_groups=display_groups, save=True)

# %%
ic = ImgCompare('ED-v3rain1400', single=False, progress_func=tqdm, particulars=particulars)
ic.find_metrics(display_groups=display_groups, save=True)

# %%
ic = ImgCompare('ED-v4rain1400', single=False, progress_func=tqdm, particulars=particulars)
ic.find_metrics(display_groups=display_groups, save=True)

# %% [markdown]
# # RCDNet

# %% [markdown]
# SPA

# %%
ic = ImgCompare('RCDNet-spa', single=False, progress_func=tqdm, particulars=particulars)
ic.find_metrics(display_groups=display_groups, save=True)

# %% [markdown]
# Rain100H

# %%
ic = ImgCompare('RCDNet-rain100h', single=False, progress_func=tqdm, particulars=particulars)
ic.find_metrics(display_groups=display_groups, save=True)

# %% [markdown]
# # SPANet

# %%
ic = ImgCompare('SPANet', single=False, progress_func=tqdm, particulars=particulars)
ic.find_metrics(display_groups=display_groups, save=True)

# %% [markdown]
# # MPRNet

# %%
ic = ImgCompare('MPRNet', single=False, progress_func=tqdm, particulars=particulars)
ic.find_metrics(display_groups=display_groups, save=True)

# %% [markdown]
# # HeavyRainRemoval

# %%
ic = ImgCompare('HRR', single=False, progress_func=tqdm, particulars=particulars)
ic.find_metrics(display_groups=display_groups, save=True)

# %% [markdown]
# # DGNL-Net

# %%
ic = ImgCompare('DGNL', single=False, progress_func=tqdm, particulars=particulars)
ic.find_metrics(display_groups=display_groups, save=True)

# %% [markdown]
# # MSPFN

# %%
ic = ImgCompare('MSPFN', single=False, progress_func=tqdm, particulars=particulars)
ic.find_metrics(display_groups=display_groups, save=True)
