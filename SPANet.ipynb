# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/WeatherNetCode/deraining-models/
# !nvidia-smi
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1v-jmrok5Mcn8HaN1GHzyJgz_evjZ-23G/WeatherNetCode/deraining-models
# Thu Oct 21 00:32:56 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# ...

# %%
# !pip install tensorboardX torch==1.2 torchvision==0.4.0
# Out:
# ...
#      |████████████████████████████████| 8.8 MB 5.3 MB/s
# ...
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.10.0+cu111
#     Uninstalling torchvision-0.10.0+cu111:
#       Successfully uninstalled torchvision-0.10.0+cu111
# ...

# %%
# !cd SPANet && python3 main.py -a test -m latest
# Out:
# 2021-10-21 01:52:56,743 - INFO - set log dir as ./logdir
# 2021-10-21 01:52:56,743 - INFO - set model dir as ./model
# Test dataset initialized with 5 rainy and 5 GTs.
# 	../images/rainy/Chehalis_0-1-Webcam-R-000.png	../images/clean/Chehalis_0-1-Webcam-C-000.png
# 	../images/rainy/Heart_0-1-Webcam-R-000.png	../images/clean/Heart_0-1-Webcam-C-000.png
# 	../images/rainy/Stick_0-0-Webcam-R-000.png	../images/clean/Stick_0-0-Webcam-C-000.png
# 	../images/rainy/Stick_0-1-Webcam-R-000.png	../images/clean/Stick_0-1-Webcam-C-000.png
# 	../images/rainy/Winter_Garden_0-2-Webcam-R-000.png	../images/clean/Winter_Garden_0-2-Webcam-C-000.png
# ...
